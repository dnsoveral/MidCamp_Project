# %%
import pandas as pd
import numpy as np

#calling libraries for Market Basket Analysis
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
bakery_data = pd.read_csv('../data/clean_data/bakery_data.csv')
bakery_data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
display(bakery_data)
# Out:
#         ticket_number        date   time               article  quantity  \
# 0            150040.0  2021-01-02  08:38              baguette       1.0
# 1            150040.0  2021-01-02  08:38      pain_au_chocolat       3.0
# 2            150041.0  2021-01-02  09:14      pain_au_chocolat       2.0
# 3            150041.0  2021-01-02  09:14                  pain       1.0
# 4            150042.0  2021-01-02  09:25  traditional_baguette       5.0
# ...               ...         ...    ...                   ...       ...
# 208072       288911.0  2022-09-30  18:52              campagne       2.0
# 208073       288911.0  2022-09-30  18:52  traditional_baguette       5.0
# 208074       288911.0  2022-09-30  18:52            boule_200g       1.0
# 208075       288912.0  2022-09-30  18:55  traditional_baguette       1.0
# 208076       288913.0  2022-09-30  18:56  traditional_baguette       1.0
#
#         unit_price  article_total
# 0             1.00           1.00
# 1             1.25           3.75
# 2             1.25           2.50
# 3             1.15           1.15
# 4             1.20           6.00
# ...            ...            ...
# 208072        1.90           3.80
# 208073        1.20           6.00
# 208074        1.10           1.10
# 208075        1.20           1.20
# 208076        1.20           1.20
#
# [208077 rows x 7 columns]

# %%
# group the DataFrame by "ticket_number" and "article" columns and calculate the count of each transaction in a ticket_number
grouped_bakery_data = bakery_data.groupby(["ticket_number", "article"]).size().reset_index(name="count")

# pivot the DataFrame to have 'articles' as columns and sum the counts
pivot_bakery_data = grouped_bakery_data.pivot_table(index="ticket_number", columns="article", values="count", aggfunc="sum", fill_value=0)

# print the aggregated DataFrame
display(pivot_bakery_data)
# Out:
# article        12_macaron  armoricain  baguette  baguette_apero  \
# ticket_number
# 150040.0                0           0         1               0
# 150041.0                0           0         0               0
# 150042.0                0           0         0               0
# 150043.0                0           0         1               0
# 150044.0                0           0         0               0
# ...                   ...         ...       ...             ...
# 288908.0                0           0         0               0
# 288910.0                0           0         0               0
# 288911.0                0           0         0               0
# 288912.0                0           0         0               0
# 288913.0                0           0         0               0
#
# article        baguette_graine  banette  banettine  boisson_33cl  bottereau  \
# ticket_number
# 150040.0                     0        0          0             0          0
# 150041.0                     0        0          0             0          0
# 150042.0                     0        0          0             0          0
# 150043.0                     0        0          0             0          0
# 150044.0                     0        1          0             0          0
# ...                        ...      ...        ...           ...        ...
# 288908.0                     0        0          0             0          0
# 288910.0                     0        0          0             0          0
# 288911.0                     0        0          0             0          0
# 288912.0                     0        0          0             0          0
# 288913.0                     0        0          0             0          0
#
# article        boule_200g  ...  tartelette_cocktail  tartelette_fraise  \
# ticket_number              ...
# 150040.0                0  ...                    0                  0
# 150041.0                0  ...                    0                  0
# 150042.0                0  ...                    0                  0
# 150043.0                0  ...                    0                  0
# 150044.0                0  ...                    0                  0
# ...                   ...  ...                  ...                ...
# 288908.0                0  ...                    0                  0
# 288910.0                0  ...                    0                  0
# 288911.0                1  ...                    0                  0
# 288912.0                0  ...                    0                  0
# 288913.0                0  ...                    0                  0
#
# article        traditional_baguette  triangles  trois_chocolat  tropezienne  \
# ticket_number
# 150040.0                          0          0               0            0
# 150041.0                          0          0               0            0
# 150042.0                          1          0               0            0
# 150043.0                          0          0               0            0
# 150044.0                          0          0               0            0
# ...                             ...        ...             ...          ...
# 288908.0                          0          0               0            0
# 288910.0                          1          0               0            0
# 288911.0                          1          0               0            0
# 288912.0                          1          0               0            0
# 288913.0                          1          0               0            0
#
# article        tropezienne_framboise  tulipe  viennoise  vik_bread
# ticket_number
# 150040.0                           0       0          0          0
# 150041.0                           0       0          0          0
# 150042.0                           0       0          0          0
# 150043.0                           0       0          0          0
# 150044.0                           0       0          0          0
# ...                              ...     ...        ...        ...
# 288908.0                           0       0          0          0
# 288910.0                           0       0          0          0
# 288911.0                           0       0          0          0
# 288912.0                           0       0          0          0
# 288913.0                           0       0          0          0
#
# [134886 rows x 123 columns]

# %%
# encoding the values to 1, if equal or greater than 1 and to 0 if smaller or equal to zero, to start applying Apriori Algorithm

def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = pivot_bakery_data.applymap(encode_units)

# %%
display(basket_sets)
# Out:
# article        12_macaron  armoricain  baguette  baguette_apero  \
# ticket_number
# 150040.0                0           0         1               0
# 150041.0                0           0         0               0
# 150042.0                0           0         0               0
# 150043.0                0           0         1               0
# 150044.0                0           0         0               0
# ...                   ...         ...       ...             ...
# 288908.0                0           0         0               0
# 288910.0                0           0         0               0
# 288911.0                0           0         0               0
# 288912.0                0           0         0               0
# 288913.0                0           0         0               0
#
# article        baguette_graine  banette  banettine  boisson_33cl  bottereau  \
# ticket_number
# 150040.0                     0        0          0             0          0
# 150041.0                     0        0          0             0          0
# 150042.0                     0        0          0             0          0
# 150043.0                     0        0          0             0          0
# 150044.0                     0        1          0             0          0
# ...                        ...      ...        ...           ...        ...
# 288908.0                     0        0          0             0          0
# 288910.0                     0        0          0             0          0
# 288911.0                     0        0          0             0          0
# 288912.0                     0        0          0             0          0
# 288913.0                     0        0          0             0          0
#
# article        boule_200g  ...  tartelette_cocktail  tartelette_fraise  \
# ticket_number              ...
# 150040.0                0  ...                    0                  0
# 150041.0                0  ...                    0                  0
# 150042.0                0  ...                    0                  0
# 150043.0                0  ...                    0                  0
# 150044.0                0  ...                    0                  0
# ...                   ...  ...                  ...                ...
# 288908.0                0  ...                    0                  0
# 288910.0                0  ...                    0                  0
# 288911.0                1  ...                    0                  0
# 288912.0                0  ...                    0                  0
# 288913.0                0  ...                    0                  0
#
# article        traditional_baguette  triangles  trois_chocolat  tropezienne  \
# ticket_number
# 150040.0                          0          0               0            0
# 150041.0                          0          0               0            0
# 150042.0                          1          0               0            0
# 150043.0                          0          0               0            0
# 150044.0                          0          0               0            0
# ...                             ...        ...             ...          ...
# 288908.0                          0          0               0            0
# 288910.0                          1          0               0            0
# 288911.0                          1          0               0            0
# 288912.0                          1          0               0            0
# 288913.0                          1          0               0            0
#
# article        tropezienne_framboise  tulipe  viennoise  vik_bread
# ticket_number
# 150040.0                           0       0          0          0
# 150041.0                           0       0          0          0
# 150042.0                           0       0          0          0
# 150043.0                           0       0          0          0
# 150044.0                           0       0          0          0
# ...                              ...     ...        ...        ...
# 288908.0                           0       0          0          0
# 288910.0                           0       0          0          0
# 288911.0                           0       0          0          0
# 288912.0                           0       0          0          0
# 288913.0                           0       0          0          0
#
# [134886 rows x 123 columns]

# %%
#creating frequent_itemsets with a minimun support of 0.004. The support is kept low to find more relationships and possibly more interesting ones

frequent_itemsets = apriori(basket_sets, min_support=0.004, use_colnames=True)
# Out:
# C:\Users\duart\ironhack.bootcamp\week_5\Mid_bootcamp_project\midcamp_env\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
# creating itemsets column with the length of its values

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x : len(x))

# %%
#showing just the itemsets with lenght inferior to 2

frequent_itemsets[frequent_itemsets['length'] < 2]
# Out:
#      support                itemsets  length
# 0   0.112740              (baguette)       1
# 1   0.011061       (baguette_graine)       1
# 2   0.111183               (banette)       1
# 3   0.020788             (banettine)       1
# 4   0.010772          (boisson_33cl)       1
# 5   0.019817            (boule_200g)       1
# 6   0.030092            (boule_400g)       1
# 7   0.012218               (brioche)       1
# 8   0.010527           (cafe_ou_eau)       1
# 9   0.028780              (campagne)       1
# 10  0.036497       (cereal_baguette)       1
# 11  0.010646   (chausson_aux_pommes)       1
# 12  0.023145               (complet)       1
# 13  0.014672                (cookie)       1
# 14  0.084419             (croissant)       1
# 15  0.013308     (croissant_amandes)       1
# 16  0.008474         (demi_baguette)       1
# 17  0.014753                (eclair)       1
# 18  0.019446               (ficelle)       1
# 19  0.007510          (financier_x5)       1
# 20  0.006094                  (flan)       1
# 21  0.004189          (flan_abricot)       1
# 22  0.030507      (formule_sandwich)       1
# 23  0.006124       (gd_kouign_amann)       1
# 24  0.010149      (grand_far_breton)       1
# 25  0.009823          (kouign_amann)       1
# 26  0.005649       (milles_feuilles)       1
# 27  0.022842               (moisson)       1
# 28  0.014138                  (pain)       1
# 29  0.077688      (pain_au_chocolat)       1
# 30  0.014672      (pain_aux_raisins)       1
# 31  0.020128          (pain_banette)       1
# 32  0.010928    (pain_choco_amandes)       1
# 33  0.006717           (paris_brest)       1
# 34  0.009616            (quim_bread)       1
# 35  0.011009      (sand_jb_emmental)       1
# 36  0.016184      (sandwich_complet)       1
# 37  0.009771                (seigle)       1
# 38  0.038188         (special_bread)       1
# 39  0.020855            (tartelette)       1
# 40  0.498169  (traditional_baguette)       1
# 41  0.023049             (vik_bread)       1

# %%
# showing just the itemsets with lenght equal or greater than 2

frequent_itemsets[frequent_itemsets['length'] >= 2]
# Out:
#      support                                           itemsets  length
# 42  0.006583                                (baguette, banette)       2
# 43  0.010898                              (croissant, baguette)       2
# 44  0.008859                       (baguette, pain_au_chocolat)       2
# 45  0.015042                   (traditional_baguette, baguette)       2
# 46  0.007087                               (croissant, banette)       2
# 47  0.005405                        (banette, pain_au_chocolat)       2
# 48  0.008830                    (traditional_baguette, banette)       2
# 49  0.005160                  (traditional_baguette, banettine)       2
# 50  0.004181                 (traditional_baguette, boule_200g)       2
# 51  0.007132                 (boule_400g, traditional_baguette)       2
# 52  0.006450                    (brioche, traditional_baguette)       2
# 53  0.006910                   (campagne, traditional_baguette)       2
# 54  0.004396            (traditional_baguette, cereal_baguette)       2
# 55  0.008466                    (traditional_baguette, complet)       2
# 56  0.005227                     (traditional_baguette, cookie)       2
# 57  0.039797                      (croissant, pain_au_chocolat)       2
# 58  0.005612                      (croissant, pain_aux_raisins)       2
# 59  0.036327                  (croissant, traditional_baguette)       2
# 60  0.004863          (croissant_amandes, traditional_baguette)       2
# 61  0.006368                     (eclair, traditional_baguette)       2
# 62  0.005160                    (ficelle, traditional_baguette)       2
# 63  0.005582           (grand_far_breton, traditional_baguette)       2
# 64  0.004344               (kouign_amann, traditional_baguette)       2
# 65  0.008555                    (moisson, traditional_baguette)       2
# 66  0.005849               (pain_au_chocolat, pain_aux_raisins)       2
# 67  0.031048           (traditional_baguette, pain_au_chocolat)       2
# 68  0.005293           (traditional_baguette, pain_aux_raisins)       2
# 69  0.004878                     (traditional_baguette, seigle)       2
# 70  0.009912              (traditional_baguette, special_bread)       2
# 71  0.008363                 (traditional_baguette, tartelette)       2
# 72  0.011832                  (traditional_baguette, vik_bread)       2
# 73  0.005241            (croissant, baguette, pain_au_chocolat)       3
# 74  0.016755  (croissant, traditional_baguette, pain_au_choc...       3

# %%
# creating rule sets, with a minimum lift of 3 to keep number of rules manageable and just show the more interesting ones
# ordering them in ascending order

rules = association_rules(frequent_itemsets, metric="lift", min_threshold=3)
rules.sort_values(by=['lift'], ignore_index=True)
# Out:
#                                  antecedents  \
# 0                         (pain_aux_raisins)
# 1                                (croissant)
# 2                         (pain_au_chocolat)
# 3                         (pain_aux_raisins)
# 4                         (pain_au_chocolat)
# 5          (croissant, traditional_baguette)
# 6                                (croissant)
# 7                         (pain_au_chocolat)
# 8                         (pain_au_chocolat)
# 9                      (croissant, baguette)
# 10  (traditional_baguette, pain_au_chocolat)
# 11                               (croissant)
# 12              (baguette, pain_au_chocolat)
# 13                               (croissant)
#
#                                  consequents  antecedent support  \
# 0                                (croissant)            0.014672
# 1                         (pain_aux_raisins)            0.084419
# 2                         (pain_aux_raisins)            0.077688
# 3                         (pain_au_chocolat)            0.014672
# 4          (croissant, traditional_baguette)            0.077688
# 5                         (pain_au_chocolat)            0.036327
# 6                         (pain_au_chocolat)            0.084419
# 7                                (croissant)            0.077688
# 8                      (croissant, baguette)            0.077688
# 9                         (pain_au_chocolat)            0.010898
# 10                               (croissant)            0.031048
# 11  (traditional_baguette, pain_au_chocolat)            0.084419
# 12                               (croissant)            0.008859
# 13              (baguette, pain_au_chocolat)            0.084419
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.084419  0.005612    0.382516  4.531142  0.004374    1.482761
# 1             0.014672  0.005612    0.066479  4.531142  0.004374    1.055497
# 2             0.014672  0.005849    0.075293  5.131901  0.004710    1.065558
# 3             0.077688  0.005849    0.398686  5.131901  0.004710    1.533828
# 4             0.036327  0.016755    0.215669  5.936895  0.013933    1.228657
# 5             0.077688  0.016755    0.461224  5.936895  0.013933    1.711867
# 6             0.077688  0.039797    0.471415  6.068065  0.033238    1.744869
# 7             0.084419  0.039797    0.512263  6.068065  0.033238    1.877200
# 8             0.010898  0.005241    0.067468  6.190833  0.004395    1.060663
# 9             0.077688  0.005241    0.480952  6.190833  0.004395    1.776932
# 10            0.084419  0.016755    0.539637  6.392332  0.014134    1.988823
# 11            0.031048  0.016755    0.198472  6.392332  0.014134    1.208880
# 12            0.084419  0.005241    0.591632  7.008242  0.004494    2.242047
# 13            0.008859  0.005241    0.062088  7.008242  0.004494    1.056753
#
#     zhangs_metric
# 0        0.790909
# 1        0.851159
# 2        0.872959
# 3        0.817129
# 4        0.901606
# 5        0.862909
# 6        0.912211
# 7        0.905553
# 8        0.909097
# 9        0.847709
# 10       0.870593
# 11       0.921342
# 12       0.864974
# 13       0.936358
